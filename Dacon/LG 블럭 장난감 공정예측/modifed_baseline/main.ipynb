# %% [markdown]
# ## [Dacon] 블럭 장난감 제조 공정 최적화 경진대회
# ## _____ (팀명)
# ## 2020년 월 일 (제출날짜)
#
# 1. 본 코드는 대회 참가를 돕고자 단순 예시를 작성한 것으로 참고용으로 사용바랍니다.
# 2. 본 코드는 자유롭게 수정하여 사용 할 수 있습니다.
# 3. 추가 모듈 보러가기: https://bit.ly/36MNs76

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
import pandas as pd
import numpy as np
import multiprocessing
import warnings
from copy import deepcopy
from module.genome import Genome, genome_score
warnings.filterwarnings(action='ignore')
np.random.seed(777)

# %%
# !python --version
print('Pandas : %s'%(pd.__version__))
print('Numpy : %s'%(np.__version__))
# Out:
# Python 3.7.7Pandas : 1.0.3
#
# Numpy : 1.18.1

# %% [markdown]
# ## 2. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %%
# 입력하세요.

# %% [markdown]
# ## 3. 탐색적 자료분석
# ## Exploratory Data Analysis

# %%
# 입력하세요.

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
CPU_CORE = int( multiprocessing.cpu_count() / 4 ) # 멀티프로세싱 CPU 사용 수. 반만 사용
N_POPULATION = 50                      # 세대당 생성수
N_BEST = 5                             # 베스트 수
N_CHILDREN = 5                         # 자손 유전자 수
PROB_MUTATION = 0.3                    # 돌연변이
REVERSE = False                        # 배열 순서 (False: ascending order, True: descending order)

score_ini = 1e8                        # 초기 점수
input_length = 125                     # 입력 데이터 길이
output_length_1 = 5                    # Event (CHECK_1~4, PROCESS)
# output_length_2 = 12                   # MOL(0~5.5, step:0.5)
output_length_2 = 1
h1 = 50                                # 히든레이어1 노드 수
h2 = 50                                # 히든레이어2 노드 수
h3 = 50                                # 히든레이어3 노드 수
EPOCHS = 200                            # 반복 횟수

genomes = []
for _ in range(N_POPULATION):
    genome = Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3)
    genomes.append(genome)
try:
    for i in range(N_BEST):
        genomes[i] = best_genomes[i]
except:
    best_genomes = []
    for _ in range(5):
        genome = Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3)
        best_genomes.append(genome)

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation
# 1. PRT는 고정값 사용
# 2. Event A, Event B (MOL_A, MOL_B) 를 같은 값으로 제한
# 3. Event는 CHECK와 PROCESS 만 사용함
# 4. 목적 함수로 수요 부족분만 고려함
# 5. Event와 MOL에 대해 인공신경망 모델을 만들어 유전 알고리즘으로 학습

# %%
n_gen = 1
score_history = []
high_score_history = []
mean_score_history = []
while n_gen <= EPOCHS:    
    genomes = np.array(genomes)    
    while len(genomes)%CPU_CORE != 0:
        genomes = np.append(genomes, Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3))
    genomes = genomes.reshape((len(genomes)//CPU_CORE, CPU_CORE))
    
    for idx, _genomes in enumerate(genomes):
        if __name__ == '__main__':
            pool = multiprocessing.Pool(processes=CPU_CORE)
            genomes[idx] = pool.map(genome_score, _genomes)
            pool.close()
            pool.join()    
    genomes = list(genomes.reshape(genomes.shape[0]*genomes.shape[1]))    
    
     # score에 따라 정렬
    genomes.sort(key=lambda x: x.score, reverse=REVERSE)
    
    # 평균 점수
    s = 0 
    for i in range(N_BEST):
        s += genomes[i].score
    s /= N_BEST
    
    # Best Score
    bs = genomes[0].score 
    
    # Best Model 추가
    if best_genomes is not None:
        genomes.extend(best_genomes)
        
    # score에 따라 정렬
    genomes.sort(key=lambda x: x.score, reverse=REVERSE)
    
    score_history.append([n_gen, genomes[0].score])
    high_score_history.append([n_gen, bs])
    mean_score_history.append([n_gen, s])
    
    # 결과 출력
    print('EPOCH #%s\tHistory Best Score: %s\tBest Score: %s\tMean Score: %s' % (n_gen, genomes[0].score, bs, s))    
    
    # 모델 업데이트
    best_genomes = deepcopy(genomes[:N_BEST])
    
    # CHILDREN 생성
    for i in range(N_CHILDREN):
        new_genome = deepcopy(best_genomes[0])
        a_genome = np.random.choice(best_genomes)
        b_genome = np.random.choice(best_genomes)
        
        for j in range(input_length):
            cut = np.random.randint(new_genome.w1.shape[1])
            new_genome.w1[j, :cut] = a_genome.w1[j, :cut]
            new_genome.w1[j, cut:] = b_genome.w1[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w2.shape[1])
            new_genome.w2[j, :cut] = a_genome.w2[j, :cut]
            new_genome.w2[j, cut:] = b_genome.w2[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w3.shape[1])
            new_genome.w3[j, :cut] = a_genome.w3[j, :cut]
            new_genome.w3[j, cut:] = b_genome.w3[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w4.shape[1])
            new_genome.w4[j, :cut] = a_genome.w4[j, :cut]
            new_genome.w4[j, cut:] = b_genome.w4[j, cut:]
            
        for j in range(input_length):
            cut = np.random.randint(new_genome.w5.shape[1])
            new_genome.w5[j, :cut] = a_genome.w5[j, :cut]
            new_genome.w5[j, cut:] = b_genome.w5[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w6.shape[1])
            new_genome.w6[j, :cut] = a_genome.w6[j, :cut]
            new_genome.w6[j, cut:] = b_genome.w6[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w7.shape[1])
            new_genome.w7[j, :cut] = a_genome.w7[j, :cut]
            new_genome.w7[j, cut:] = b_genome.w7[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w8.shape[1])
            new_genome.w8[j, :cut] = a_genome.w8[j, :cut]
            new_genome.w8[j, cut:] = b_genome.w8[j, cut:]
        
        for j in range(input_length):
            cut = np.random.randint(new_genome.w9.shape[1])
            new_genome.w9[j, :cut] = a_genome.w9[j, :cut]
            new_genome.w9[j, cut:] = b_genome.w9[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w10.shape[1])
            new_genome.w10[j, :cut] = a_genome.w10[j, :cut]
            new_genome.w10[j, cut:] = b_genome.w10[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w11.shape[1])
            new_genome.w11[j, :cut] = a_genome.w11[j, :cut]
            new_genome.w11[j, cut:] = b_genome.w11[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w12.shape[1])
            new_genome.w12[j, :cut] = a_genome.w12[j, :cut]
            new_genome.w12[j, cut:] = b_genome.w12[j, cut:]
            
        for j in range(input_length):
            cut = np.random.randint(new_genome.w13.shape[1])
            new_genome.w13[j, :cut] = a_genome.w13[j, :cut]
            new_genome.w13[j, cut:] = b_genome.w13[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w14.shape[1])
            new_genome.w14[j, :cut] = a_genome.w14[j, :cut]
            new_genome.w14[j, cut:] = b_genome.w14[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w15.shape[1])
            new_genome.w15[j, :cut] = a_genome.w15[j, :cut]
            new_genome.w15[j, cut:] = b_genome.w15[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w16.shape[1])
            new_genome.w16[j, :cut] = a_genome.w16[j, :cut]
            new_genome.w16[j, cut:] = b_genome.w16[j, cut:]
        
        best_genomes.append(new_genome)
    
    # 모델 초기화
    genomes = []
    for i in range(int(N_POPULATION / len(best_genomes))):
        for bg in best_genomes:
            new_genome = deepcopy(bg)            
            mean = 0
            stddev = 0.2                        
            # 50% 확률로 모델 변형
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w1 += new_genome.w1 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w2 += new_genome.w2 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w3 += new_genome.w3 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w4 += new_genome.w4 * np.random.normal(mean, stddev, size=(h3, output_length_1)) * np.random.randint(0, 2, (h3, output_length_1))                
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w5 += new_genome.w5 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w6 += new_genome.w6 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w7 += new_genome.w7 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w8 += new_genome.w8 * np.random.normal(mean, stddev, size=(h3, output_length_2)) * np.random.randint(0, 2, (h3, output_length_2))

            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w9 += new_genome.w9 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w10 += new_genome.w10 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w11 += new_genome.w11 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w12 += new_genome.w12 * np.random.normal(mean, stddev, size=(h3, output_length_1)) * np.random.randint(0, 2, (h3, output_length_1))                
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w13 += new_genome.w13 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w14 += new_genome.w14 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w15 += new_genome.w15 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w16 += new_genome.w16 * np.random.normal(mean, stddev, size=(h3, output_length_2)) * np.random.randint(0, 2, (h3, output_length_2))
            
            genomes.append(new_genome)
            
    if REVERSE:
        if bs < score_ini:
            genomes[len(genomes)//2:] = [Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3) for _ in range(N_POPULATION//2)]
    else:
        if bs > score_ini:
            genomes[len(genomes)//2:] = [Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3) for _ in range(N_POPULATION//2)]  
        
    n_gen += 1
# Out:
# EPOCH #1	History Best Score: 72973981.0	Best Score: 72973981.0	Mean Score: 80173826.8
# EPOCH #2	History Best Score: 60339458.0	Best Score: 60339458.0	Mean Score: 64754675.2
# EPOCH #3	History Best Score: 56562894.0	Best Score: 56562894.0	Mean Score: 58902431.8
# EPOCH #4	History Best Score: 56164903.0	Best Score: 56164903.0	Mean Score: 58541416.2
# EPOCH #5	History Best Score: 53218447.0	Best Score: 53218447.0	Mean Score: 56157149.6
# EPOCH #6	History Best Score: 47773039.0	Best Score: 47773039.0	Mean Score: 53453520.0
# EPOCH #7	History Best Score: 47773039.0	Best Score: 50313639.0	Mean Score: 54547740.6
# EPOCH #8	History Best Score: 47773039.0	Best Score: 51743578.0	Mean Score: 52933395.4
# EPOCH #9	History Best Score: 47773039.0	Best Score: 52755426.0	Mean Score: 54215097.8
# EPOCH #10	History Best Score: 47773039.0	Best Score: 52419078.0	Mean Score: 54298796.2
# EPOCH #11	History Best Score: 47773039.0	Best Score: 51279750.0	Mean Score: 52335115.2
# EPOCH #12	History Best Score: 47773039.0	Best Score: 51056310.0	Mean Score: 52564595.8
# EPOCH #13	History Best Score: 47773039.0	Best Score: 49414656.0	Mean Score: 51692302.4
# EPOCH #14	History Best Score: 47773039.0	Best Score: 49314728.0	Mean Score: 51150908.4
# EPOCH #15	History Best Score: 46888444.0	Best Score: 46888444.0	Mean Score: 50916068.2
# EPOCH #16	History Best Score: 46888444.0	Best Score: 47828351.0	Mean Score: 50769664.8
# EPOCH #17	History Best Score: 46888444.0	Best Score: 48193400.0	Mean Score: 50160618.8
# EPOCH #18	History Best Score: 46888444.0	Best Score: 48429018.0	Mean Score: 51033633.6
# EPOCH #19	History Best Score: 46888444.0	Best Score: 53188057.0	Mean Score: 55659510.6
# EPOCH #20	History Best Score: 46888444.0	Best Score: 48992170.0	Mean Score: 51607977.4
# EPOCH #21	History Best Score: 46888444.0	Best Score: 49122120.0	Mean Score: 50700734.6
# EPOCH #22	History Best Score: 46888444.0	Best Score: 47972313.0	Mean Score: 52128109.4
# EPOCH #23	History Best Score: 46888444.0	Best Score: 48394370.0	Mean Score: 50534085.8
# EPOCH #24	History Best Score: 46590441.0	Best Score: 46590441.0	Mean Score: 50128345.4
# EPOCH #25	History Best Score: 46590441.0	Best Score: 47187999.0	Mean Score: 48351159.8
# EPOCH #26	History Best Score: 46590441.0	Best Score: 47233147.0	Mean Score: 48835766.0
# EPOCH #27	History Best Score: 46590441.0	Best Score: 47208989.0	Mean Score: 50269303.2
# EPOCH #28	History Best Score: 46590441.0	Best Score: 46602504.0	Mean Score: 47570639.8
# EPOCH #29	History Best Score: 46590441.0	Best Score: 47863532.0	Mean Score: 49264565.8
# EPOCH #30	History Best Score: 46028435.0	Best Score: 46028435.0	Mean Score: 48670963.6
# EPOCH #31	History Best Score: 46028435.0	Best Score: 47371963.0	Mean Score: 49023650.0
# EPOCH #32	History Best Score: 45638808.0	Best Score: 45638808.0	Mean Score: 47899837.8
# EPOCH #33	History Best Score: 45638808.0	Best Score: 46082308.0	Mean Score: 47018183.2
# EPOCH #34	History Best Score: 44679449.0	Best Score: 44679449.0	Mean Score: 48116200.8
# EPOCH #35	History Best Score: 44679449.0	Best Score: 48073356.0	Mean Score: 49256053.6
# EPOCH #36	History Best Score: 44679449.0	Best Score: 48289588.0	Mean Score: 49539555.2
# EPOCH #37	History Best Score: 44679449.0	Best Score: 47489612.0	Mean Score: 48895842.8
# EPOCH #38	History Best Score: 44679449.0	Best Score: 45871615.0	Mean Score: 47445216.2
# EPOCH #39	History Best Score: 44679449.0	Best Score: 46762934.0	Mean Score: 48358397.4
# EPOCH #40	History Best Score: 44679449.0	Best Score: 46532042.0	Mean Score: 48238722.0
# EPOCH #41	History Best Score: 44679449.0	Best Score: 47288127.0	Mean Score: 49251080.4
# EPOCH #42	History Best Score: 44679449.0	Best Score: 49937524.0	Mean Score: 50460018.0
# EPOCH #43	History Best Score: 44679449.0	Best Score: 49618659.0	Mean Score: 51086560.2
# EPOCH #44	History Best Score: 44679449.0	Best Score: 46640574.0	Mean Score: 48125301.6
# EPOCH #45	History Best Score: 44679449.0	Best Score: 48120849.0	Mean Score: 48955360.2
# EPOCH #46	History Best Score: 44679449.0	Best Score: 48321405.0	Mean Score: 49314732.4
# EPOCH #47	History Best Score: 44679449.0	Best Score: 46017483.0	Mean Score: 47108186.2
# EPOCH #48	History Best Score: 44679449.0	Best Score: 45559707.0	Mean Score: 48248441.6
# EPOCH #49	History Best Score: 44679449.0	Best Score: 49789057.0	Mean Score: 50764215.2
# EPOCH #50	History Best Score: 44679449.0	Best Score: 49109987.0	Mean Score: 50293278.0
# EPOCH #51	History Best Score: 44679449.0	Best Score: 46918878.0	Mean Score: 49776574.2
# EPOCH #52	History Best Score: 44679449.0	Best Score: 46722916.0	Mean Score: 47909175.2
# EPOCH #53	History Best Score: 44679449.0	Best Score: 48044123.0	Mean Score: 49725770.6
# EPOCH #54	History Best Score: 44679449.0	Best Score: 49176450.0	Mean Score: 49655321.8
# EPOCH #55	History Best Score: 44679449.0	Best Score: 46319397.0	Mean Score: 48012279.0
# EPOCH #56	History Best Score: 44679449.0	Best Score: 48087356.0	Mean Score: 49220936.4
# EPOCH #57	History Best Score: 44679449.0	Best Score: 47720177.0	Mean Score: 48271606.8
# EPOCH #58	History Best Score: 44679449.0	Best Score: 47200005.0	Mean Score: 48857257.8
# EPOCH #59	History Best Score: 44679449.0	Best Score: 48669472.0	Mean Score: 49611781.8
# EPOCH #60	History Best Score: 44679449.0	Best Score: 48146076.0	Mean Score: 49112136.2
# EPOCH #61	History Best Score: 44679449.0	Best Score: 48051425.0	Mean Score: 50189382.0
# EPOCH #62	History Best Score: 44679449.0	Best Score: 45420590.0	Mean Score: 47483785.8
# EPOCH #63	History Best Score: 44679449.0	Best Score: 50409666.0	Mean Score: 51426066.8
# EPOCH #64	History Best Score: 44679449.0	Best Score: 45853452.0	Mean Score: 47646008.6
# EPOCH #65	History Best Score: 44679449.0	Best Score: 48000872.0	Mean Score: 50097266.8
# EPOCH #66	History Best Score: 44679449.0	Best Score: 48411134.0	Mean Score: 49263547.4
# EPOCH #67	History Best Score: 44679449.0	Best Score: 50363024.0	Mean Score: 50758302.0
# EPOCH #68	History Best Score: 44679449.0	Best Score: 47656804.0	Mean Score: 48648882.4
# EPOCH #69	History Best Score: 44679449.0	Best Score: 45899562.0	Mean Score: 47976131.4
# EPOCH #70	History Best Score: 44679449.0	Best Score: 46025134.0	Mean Score: 47259301.0
# EPOCH #71	History Best Score: 44679449.0	Best Score: 47320670.0	Mean Score: 48530521.4
# EPOCH #72	History Best Score: 44679449.0	Best Score: 45288746.0	Mean Score: 48820736.4
# EPOCH #73	History Best Score: 44679449.0	Best Score: 49631090.0	Mean Score: 52142053.8
# EPOCH #74	History Best Score: 44679449.0	Best Score: 47619358.0	Mean Score: 48320494.0
# EPOCH #75	History Best Score: 44679449.0	Best Score: 50012819.0	Mean Score: 51061612.4
# EPOCH #76	History Best Score: 44679449.0	Best Score: 45624420.0	Mean Score: 47704330.4
# EPOCH #77	History Best Score: 44679449.0	Best Score: 46419319.0	Mean Score: 47018051.6
# EPOCH #78	History Best Score: 44679449.0	Best Score: 46747767.0	Mean Score: 49160723.6
# EPOCH #79	History Best Score: 44679449.0	Best Score: 47914517.0	Mean Score: 48984260.4
# EPOCH #80	History Best Score: 44679449.0	Best Score: 46924016.0	Mean Score: 48250797.0
# EPOCH #81	History Best Score: 44679449.0	Best Score: 48184806.0	Mean Score: 48865270.2
# EPOCH #82	History Best Score: 44679449.0	Best Score: 45748531.0	Mean Score: 47982584.6
# EPOCH #83	History Best Score: 44679449.0	Best Score: 47372184.0	Mean Score: 49369810.2
# EPOCH #84	History Best Score: 44679449.0	Best Score: 45361070.0	Mean Score: 47737105.6
# EPOCH #85	History Best Score: 44679449.0	Best Score: 48181080.0	Mean Score: 49400956.8
# EPOCH #86	History Best Score: 44679449.0	Best Score: 46865078.0	Mean Score: 49585073.8
# EPOCH #87	History Best Score: 44679449.0	Best Score: 45200910.0	Mean Score: 47003302.4
# EPOCH #88	History Best Score: 44679449.0	Best Score: 45014745.0	Mean Score: 46562555.2
# EPOCH #89	History Best Score: 43793297.0	Best Score: 43793297.0	Mean Score: 47963524.6
# EPOCH #90	History Best Score: 43793297.0	Best Score: 46530481.0	Mean Score: 48020393.0
# EPOCH #91	History Best Score: 43793297.0	Best Score: 45873048.0	Mean Score: 48462752.4
# EPOCH #92	History Best Score: 43793297.0	Best Score: 48935376.0	Mean Score: 49492889.8
# EPOCH #93	History Best Score: 43793297.0	Best Score: 49748560.0	Mean Score: 50701139.0
# EPOCH #94	History Best Score: 43793297.0	Best Score: 45906341.0	Mean Score: 48005603.2
# EPOCH #95	History Best Score: 43793297.0	Best Score: 46373099.0	Mean Score: 48268999.0
# EPOCH #96	History Best Score: 43793297.0	Best Score: 47147235.0	Mean Score: 48429174.2
# EPOCH #97	History Best Score: 43793297.0	Best Score: 45711359.0	Mean Score: 47438544.8
# EPOCH #98	History Best Score: 43793297.0	Best Score: 46279927.0	Mean Score: 48591541.0
# EPOCH #99	History Best Score: 43793297.0	Best Score: 48096219.0	Mean Score: 49420386.0
# EPOCH #100	History Best Score: 43793297.0	Best Score: 44494711.0	Mean Score: 46608768.2

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion

# %% [markdown]
# ### 결과 그래프

# %%
import matplotlib.pyplot as plt

# Score Graph
score_history = np.array(score_history)
high_score_history = np.array(high_score_history)
mean_score_history = np.array(mean_score_history)

plt.plot(score_history[:,0], score_history[:,1], '-o', label='BEST')
plt.plot(high_score_history[:,0], high_score_history[:,1], '-o', label='High')
plt.plot(mean_score_history[:,0], mean_score_history[:,1], '-o', label='Mean')
plt.legend()
plt.xlim(0, EPOCHS)
plt.ylim(bottom=0)
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ### Submission 파일 만들기

# %%
# 재고 계산
from module.simulator import Simulator
simulator = Simulator()
order = pd.read_csv('module/order.csv')
submission = best_genomes[0].predict(order)
_, df_stock = simulator.get_score(submission) 

# PRT 개수 계산
PRTs = df_stock[['PRT_1', 'PRT_2', 'PRT_3', 'PRT_4']].values
PRTs = (PRTs[:-1] - PRTs[1:])[24*23:]
PRTs = np.ceil(PRTs * 1.1)
PAD = np.zeros((24*23+1, 4))
PRTs = np.append(PRTs, PAD, axis=0).astype(int)

# Submission 파일에 PRT 입력
submission.loc[:, 'PRT_1':'PRT_4'] = PRTs
submission.to_csv('200815 no_seed prob_mutation_0.3 upto_Apr_23rd divided_line out2_4_sigmoid epoch_200.csv', index=False)

# %% [markdown]
# ### 점수 향상 팁
# 해당 코드는 단순한 모델로 다음 방법으로 점수 향상을 꾀할 수 있습니다.
# 1. 성형 공정 2개 라인을 따로 모델링
# 2. CHANGE, STOP 이벤트 활용
# 3. 수요 초과분 외 다양한 양상을 반영하는 목적함수
# 4. 유전 알고리즘 외 효율적인 학습 기법
