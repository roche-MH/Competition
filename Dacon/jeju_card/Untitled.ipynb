# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('201901-202003.csv')
data = data.fillna('')

# %%
df = data.copy()
df = df[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False)
df = df.loc[df['REG_YYMM']==201903]
df = df[['CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]

# %%
submission = pd.read_csv('submission.csv', index_col=0)
submission = submission.loc[submission['REG_YYMM']==202004]
submission = submission[['CARD_SIDO_NM', 'STD_CLSS_NM']]
submission = submission.merge(df, left_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission = submission.fillna(0)
AMT = list(submission['AMT'])*2

submission = pd.read_csv('submission.csv', index_col=0)
submission['AMT'] = AMT
submission.to_csv('dacon_submission.csv', encoding='utf-8-sig')
submission.head()
# Out:
#     REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# id
# 0     202004           강원            건강보조식품 소매업  1.094390e+08
# 1     202004           강원               골프장 운영업  2.760497e+09
# 2     202004           강원           과실 및 채소 소매업  9.392280e+08
# 3     202004           강원     관광 민예품 및 선물용품 소매업  2.502319e+07
# 4     202004           강원  그외 기타 분류안된 오락관련 서비스업  0.000000e+00

# %%
df = data.copy()

# %%
df = df[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
print(df)
# Out:
#           REG_YYMM CARD_SIDO_NM STD_CLSS_NM      AMT
# 0           201901           강원  건강보조식품 소매업   311200
# 1           201901           강원  건강보조식품 소매업  1374500
# 2           201901           강원  건강보조식품 소매업   818700
# 3           201901           강원  건강보조식품 소매업  1717000
# 4           201901           강원  건강보조식품 소매업  1047300
# ...            ...          ...         ...      ...
# 24697787    202003           충북    휴양콘도 운영업    43300
# 24697788    202003           충북    휴양콘도 운영업    35000
# 24697789    202003           충북    휴양콘도 운영업   188000
# 24697790    202003           충북    휴양콘도 운영업    99000
# 24697791    202003           충북    휴양콘도 운영업   194000
#
# [24697792 rows x 4 columns]

# %%
df = df.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False)
print(df)
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM          AMT
# 0       201901           강원             건강보조식품 소매업    148354746
# 1       201901           강원                골프장 운영업   1229200312
# 2       201901           강원            과실 및 채소 소매업   1286979106
# 3       201901           강원      관광 민예품 및 선물용품 소매업     30656770
# 4       201901           강원        그외 기타 스포츠시설 운영업     13101500
# ...        ...          ...                    ...          ...
# 9433    202003           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299
# 9434    202003           충북                한식 음식점업  16152482704
# 9435    202003           충북                    호텔업     15248550
# 9436    202003           충북          화장품 및 방향제 소매업    428881434
# 9437    202003           충북               휴양콘도 운영업     12733490
#
# [9438 rows x 4 columns]

# %%
df = df.loc[df['REG_YYMM']==201903]
print(df)
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM          AMT
# 1258    201903           강원             건강보조식품 소매업    109439025
# 1259    201903           강원                골프장 운영업   2760497139
# 1260    201903           강원            과실 및 채소 소매업    939227950
# 1261    201903           강원      관광 민예품 및 선물용품 소매업     25023190
# 1262    201903           강원        그외 기타 스포츠시설 운영업      6817720
# ...        ...          ...                    ...          ...
# 1883    201903           충북  피자 햄버거 샌드위치 및 유사 음식점업   1441131811
# 1884    201903           충북                한식 음식점업  22952482750
# 1885    201903           충북                    호텔업     36030010
# 1886    201903           충북          화장품 및 방향제 소매업    729328422
# 1887    201903           충북               휴양콘도 운영업    107431443
#
# [630 rows x 4 columns]

# %%
df = df[['CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
print(df)
# Out:
#      CARD_SIDO_NM            STD_CLSS_NM          AMT
# 1258           강원             건강보조식품 소매업    109439025
# 1259           강원                골프장 운영업   2760497139
# 1260           강원            과실 및 채소 소매업    939227950
# 1261           강원      관광 민예품 및 선물용품 소매업     25023190
# 1262           강원        그외 기타 스포츠시설 운영업      6817720
# ...           ...                    ...          ...
# 1883           충북  피자 햄버거 샌드위치 및 유사 음식점업   1441131811
# 1884           충북                한식 음식점업  22952482750
# 1885           충북                    호텔업     36030010
# 1886           충북          화장품 및 방향제 소매업    729328422
# 1887           충북               휴양콘도 운영업    107431443
#
# [630 rows x 3 columns]

# %% [markdown]
# # submission

# %%
submission = pd.read_csv('submission.csv', index_col=0)
print(submission)
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM  AMT
# id
# 0       202004           강원             건강보조식품 소매업    0
# 1       202004           강원                골프장 운영업    0
# 2       202004           강원            과실 및 채소 소매업    0
# 3       202004           강원      관광 민예품 및 선물용품 소매업    0
# 4       202004           강원   그외 기타 분류안된 오락관련 서비스업    0
# ...        ...          ...                    ...  ...
# 1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업    0
# 1390    202007           충북                한식 음식점업    0
# 1391    202007           충북                    호텔업    0
# 1392    202007           충북          화장품 및 방향제 소매업    0
# 1393    202007           충북               휴양콘도 운영업    0
#
# [1394 rows x 4 columns]

# %%
submission = submission.loc[submission['REG_YYMM']==202004]
print(submission)
# Out:
#      REG_YYMM CARD_SIDO_NM            STD_CLSS_NM  AMT
# id
# 0      202004           강원             건강보조식품 소매업    0
# 1      202004           강원                골프장 운영업    0
# 2      202004           강원            과실 및 채소 소매업    0
# 3      202004           강원      관광 민예품 및 선물용품 소매업    0
# 4      202004           강원   그외 기타 분류안된 오락관련 서비스업    0
# ..        ...          ...                    ...  ...
# 692    202004           충북  피자 햄버거 샌드위치 및 유사 음식점업    0
# 693    202004           충북                한식 음식점업    0
# 694    202004           충북                    호텔업    0
# 695    202004           충북          화장품 및 방향제 소매업    0
# 696    202004           충북               휴양콘도 운영업    0
#
# [697 rows x 4 columns]

# %%
submission = submission[['CARD_SIDO_NM', 'STD_CLSS_NM']]
print(submission)
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM
# id
# 0             강원             건강보조식품 소매업
# 1             강원                골프장 운영업
# 2             강원            과실 및 채소 소매업
# 3             강원      관광 민예품 및 선물용품 소매업
# 4             강원   그외 기타 분류안된 오락관련 서비스업
# ..           ...                    ...
# 692           충북  피자 햄버거 샌드위치 및 유사 음식점업
# 693           충북                한식 음식점업
# 694           충북                    호텔업
# 695           충북          화장품 및 방향제 소매업
# 696           충북               휴양콘도 운영업
#
# [697 rows x 2 columns]

# %%
submission = submission.merge(df, left_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0             강원             건강보조식품 소매업  1.094390e+08
# 1             강원                골프장 운영업  2.760497e+09
# 2             강원            과실 및 채소 소매업  9.392280e+08
# 3             강원      관광 민예품 및 선물용품 소매업  2.502319e+07
# 4             강원   그외 기타 분류안된 오락관련 서비스업           NaN
# ..           ...                    ...           ...
# 692           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.441132e+09
# 693           충북                한식 음식점업  2.295248e+10
# 694           충북                    호텔업  3.603001e+07
# 695           충북          화장품 및 방향제 소매업  7.293284e+08
# 696           충북               휴양콘도 운영업  1.074314e+08
#
# [697 rows x 3 columns]

# %%
submission = submission.fillna(0)
print(submission)
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0             강원             건강보조식품 소매업  1.094390e+08
686100.0, 2442516266.0, 1223679050.0, 949765560.0, 3495750.0, 13525300.0, 0.0, 1900607522.0, 876780327.0, 15174825893.0, 8612387130.0, 62300.0, 2162895215.0, 31054838075.0, 50789515.0, 1185750463.0, 0.0, 265797342.0, 268961445.0, 2236560070.0, 38131020.0, 0.0, 10987500.0, 1444410130.0, 25454127230.0, 1603700.0, 1926800963.0, 384362160.0, 2026101205.0, 0.0, 15001600.0, 298613760.0, 1656000.0, 3929631260.0, 3659864511.0, 6465418229.0, 1422417235.0, 29957410414.0, 4697769833.0, 799465474.0, 1100000.0, 708719816.0, 5413824722.0, 1295410205.0, 2782193206.0, 4747480.0, 236058620.0, 0.0, 3126397848.0, 1214118650.0, 24599606231.0, 14816087191.0, 6347327300.0, 4237775113.0, 54176102491.0, 402020726.0, 2357584259.0, 0.0, 112213711.0, 241778140.0, 801442722.0, 23575152.0, 0.0, 676500.0, 1130010190.0, 10068224794.0, 239700.0, 1257380461.0, 158209655.0, 1301370405.0, 0.0, 19390077.0, 0.0, 0.0, 1346026205.0, 2100370544.0, 2812890060.0, 696621510.0, 8315258224.0, 1328146779.0, 412637942.0, 0.0, 298203175.0, 1724393883.0, 179256600.0, 1016129527.0, 824000.0, 42312150.0, 0.0, 1505638868.0, 555212614.0, 9605412668.0, 6661914672.0, 0.0, 1605168622.0, 21318098423.0, 153375541.0, 790336002.0, 0.0, 443405946.0, 1382101816.0, 4612243665.0, 75543660.0, 0.0, 16014300.0, 1660986720.0, 67654915612.0, 3112300.0, 2754228841.0, 1828033126.0, 1003842219.0, 3682200.0, 42537546.0, 3218109294.0, 2801500.0, 5286548935.0, 5071774409.0, 9238192832.0, 844180073.0, 26214621896.0, 7364733024.0, 1741671840.0, 32917100.0, 1651557297.0, 4429140480.0, 4499897697.0, 4660855090.0, 9469519.0, 380071140.0, 394 ...

# %%
submission = pd.read_csv('submission.csv', index_col=0)
print(submission)
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM  AMT
# id
# 0       202004           강원             건강보조식품 소매업    0
# 1       202004           강원                골프장 운영업    0
# 2       202004           강원            과실 및 채소 소매업    0
# 3       202004           강원      관광 민예품 및 선물용품 소매업    0
# 4       202004           강원   그외 기타 분류안된 오락관련 서비스업    0
# ...        ...          ...                    ...  ...
# 1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업    0
# 1390    202007           충북                한식 음식점업    0
# 1391    202007           충북                    호텔업    0
# 1392    202007           충북          화장품 및 방향제 소매업    0
# 1393    202007           충북               휴양콘도 운영업    0
#
# [1394 rows x 4 columns]

# %%
submission['AMT'] = AMT
print(submission)
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# id
# 0       202004           강원             건강보조식품 소매업  1.094390e+08
# 1       202004           강원                골프장 운영업  2.760497e+09
# 2       202004           강원            과실 및 채소 소매업  9.392280e+08
# 3       202004           강원      관광 민예품 및 선물용품 소매업  2.502319e+07
# 4       202004           강원   그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ...        ...          ...                    ...           ...
# 1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.441132e+09
# 1390    202007           충북                한식 음식점업  2.295248e+10
# 1391    202007           충북                    호텔업  3.603001e+07
# 1392    202007           충북          화장품 및 방향제 소매업  7.293284e+08
# 1393    202007           충북               휴양콘도 운영업  1.074314e+08
#
# [1394 rows x 4 columns]

# %%
submission.to_csv('dacon_submission.csv', encoding='utf-8-sig')
