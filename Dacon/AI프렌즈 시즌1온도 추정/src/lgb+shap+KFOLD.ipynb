# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train = train.loc[:, train.max() != train.min()]
test = test.loc[:, test.max() != test.min()]

# %%
train['Y18'].isnull().sum(), train['Y18'].notnull().sum()
train_first_30 = train[train['Y18'].isnull()]
train_first_30.shape
train_later_3 = train[train['Y18'].notnull()]
train_later_3.shape
# Out:
# (432, 57)

# %%
X_train = train_first_30.loc[:, 'X00':'X39']
X_train
X_train = pd.concat([X_train, X_train], axis=0)
X_train = pd.concat([X_train, X_train], axis=0)
X_train = pd.concat([X_train, train_later_3.loc[:, 'X00':'X39']], axis=0)
X_train = pd.concat([X_train, train_later_3.loc[:, 'X00':'X39']], axis=0)
X_train = pd.concat([X_train, train_later_3.loc[:, 'X00':'X39']], axis=0)
X_train
# Out:
#        X00    X01  X02  X03  X04     X05  ...    X34    X35  X36   X37   X38  X39
# 0      9.7  988.8  1.2  0.6  0.0  1009.3  ...   0.00  256.4  0.0  77.2  62.6  0.0
# 1      9.3  988.9  1.7  1.9  0.0  1009.3  ...   0.00  215.4  0.0  77.3  63.5  0.0
# 2      9.4  989.0  1.1  2.3  0.0  1009.2  ...   0.00  235.2  0.0  77.3  63.9  0.0
# 3      9.4  988.9  1.5  0.7  0.0  1009.2  ...   0.00  214.0  0.0  77.5  64.5  0.0
# 4      9.2  988.9  0.8  1.7  0.0  1009.2  ...   0.00  174.9  0.0  78.0  65.0  0.0
# ...    ...    ...  ...  ...  ...     ...  ...    ...    ...  ...   ...   ...  ...
# 4747  19.9  987.6  0.9  0.8  0.0  1006.9  ...  22.16  218.6  0.0  82.3  58.6  0.5
# 4748  19.9  987.6  0.5  0.7  0.0  1006.8  ...  22.16  161.7  0.0  82.5  59.1  0.5
# 4749  19.7  987.7  0.9  0.6  0.0  1006.9  ...  22.16  254.2  0.0  83.0  58.9  0.5
# 4750  19.4  987.7  0.9  0.8  0.0  1006.9  ...  22.16  300.0  0.0  83.2  59.8  0.5
# 4751  19.1  987.6  1.0  0.3  0.0  1006.8  ...  22.16  157.5  0.0  84.0  59.5  0.5
#
# [18576 rows x 37 columns]

# %%
def momentValue(df, columns):
    for column in columns:
        temp_df = pd.DataFrame(df[column])
        temp_df['dummy'] = 0
        
        for i in range(1, temp_df.shape[0]):
            a = temp_df[column].iloc[i] - temp_df[column].iloc[i-1]
            if a > 0:
                temp_df['dummy'].iloc[i] = a
        
        df[column] = temp_df['dummy']
    
    return df

# %%
X_train = momentValue(X_train,['X11','X34'])
X_train = momentValue(X_train,['X04','X10','X21','X36','X39'])
test = momentValue(test,['X11','X34'])
test = momentValue(test,['X04','X10','X21','X36','X39'])
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
def scale(df):
  df/=df.max()
  return df

# %%
select_Tr = X_train.loc[:,['X13','X15','X17','X25','X35','X01','X06','X22','X27','X29','X05','X08','X09','X23','X33']]
select_Ts = test.loc[:,['X13','X15','X17','X25','X35','X01','X06','X22','X27','X29','X05','X08','X09','X23','X33']]

# %%
stand_Tr = X_train.loc[:,['X00','X02','X03','X04','X07','X10','X11','X12','X18','X20','X21','X24','X26','X28','X30','X31','X32','X34','X37','X38','X39']]
stand_Ts = test.loc[:,['X00','X02','X03','X04','X07','X10','X11','X12','X18','X20','X21','X24','X26','X28','X30','X31','X32','X34','X37','X38','X39']]

# %%
scale(select_Tr)
scale(select_Ts)
# Out:
#             X13       X15       X17  ...       X09       X23       X33
# 0      0.926924  0.554598  0.100000  ...  0.989488  0.989298  0.989395
# 1      0.932203  0.539039  0.354722  ...  0.989488  0.989200  0.989297
# 2      0.000000  0.480411  0.163889  ...  0.989488  0.989102  0.989297
# 3      0.702695  0.426507  0.152500  ...  0.989488  0.989102  0.989199
# 4      0.661851  0.482912  0.135556  ...  0.989488  0.989003  0.989297
# ...         ...       ...       ...  ...       ...       ...       ...
# 11515  0.182273  0.282301  0.490833  ...  0.994793  0.994502  0.994698
# 11516  0.144207  0.235621  0.521667  ...  0.994793  0.994502  0.994599
# 11517  0.080578  0.290358  0.513333  ...  0.994891  0.994600  0.994599
# 11518  0.083356  0.286191  0.521667  ...  0.994793  0.994600  0.994599
# 11519  0.076688  0.334815  0.491389  ...  0.994793  0.994698  0.994599
#
# [11520 rows x 15 columns]

# %%
#표준화 함수 생성
def standardization(df):
    mean = np.mean(df)
    std = np.std(df)
    norm = (df - mean) / (std - 1e-07)
    return norm, mean, std

# %%
# 학습데이터 표준화
X_train_norm, mean, std = standardization(stand_Tr)

# %%
y_train = train_first_30.loc[:, 'Y16']
y_train = pd.concat([y_train, y_train], axis=0)
y_train = pd.concat([y_train, y_train], axis=0)
y_train = pd.concat([y_train, train_later_3.loc[:, 'Y18']], axis=0)
y_train = pd.concat([y_train, train_later_3.loc[:, 'Y18']], axis=0)
y_train = pd.concat([y_train, train_later_3.loc[:, 'Y18']], axis=0)
y_train
# Out:
# 0        8.0
# 1        7.5
# 2        7.5
# 3        7.5
# 4        7.5
#         ...
# 4747    21.5
# 4748    21.5
# 4749    21.5
# 4750    21.5
# 4751    21.0
# Length: 18576, dtype: float64

# %%
X_test_norm = (stand_Ts - mean) / (std - 1e-07)

# %%
X_train_norm = pd.concat([X_train_norm,select_Tr],axis=1)
X_test_norm = pd.concat([X_test_norm,select_Ts],axis=1)

# %%
# ID로 시간 변수 생성
minute = pd.Series((X_train_norm.index%144).astype(int))
hour= pd.Series((X_train_norm.index%144/6).astype(int))

# 삼각함수를 이용한 시간변수 생성
min_in_day = 24*6
hour_in_day = 24

minute_sin = np.sin(np.pi*minute/min_in_day) 
minute_cos = np.cos(np.pi*minute/min_in_day)

hour_sin  = np.sin(np.pi*hour/hour_in_day)
hour_cos  = np.cos(np.pi*hour/hour_in_day)

X_train_norm['minute_sin'] = minute_sin
X_train_norm['minute_cos'] = minute_cos

X_train_norm['hour_sin'] = hour_sin
X_train_norm['hour_cos'] = hour_cos
X_train_norm
# Out:
#            X00       X02       X03  ...  minute_cos  hour_sin  hour_cos
# 0    -2.218915 -0.295509 -0.906406  ...    1.000000  0.000000  1.000000
# 1    -2.303712  0.169220  0.475687  ...    0.999762  0.000000  1.000000
# 2    -2.282513 -0.388455  0.900946  ...    0.999048  0.000000  1.000000
# 3    -2.282513 -0.016672 -0.800091  ...    0.997859  0.000000  1.000000
# 4    -2.324912 -0.667292  0.263057  ...    0.996195  0.000000  1.000000
# ...        ...       ...       ...  ...         ...       ...       ...
# 4747 -0.056582 -0.574346 -0.693777  ...   -0.994056  0.130526 -0.991445
# 4748 -0.056582 -0.946129 -0.800091  ...   -0.996195  0.130526 -0.991445
# 4749 -0.098980 -0.574346 -0.906406  ...   -0.997859  0.130526 -0.991445
# 4750 -0.162579 -0.574346 -0.693777  ...   -0.999048  0.130526 -0.991445
# 4751 -0.226177 -0.481401 -1.225351  ...   -0.999762  0.130526 -0.991445
#
# [18576 rows x 40 columns]

# %%
# ID로 시간 변수 생성
minute = pd.Series((test.id%144).astype(int))
hour= pd.Series((test.id%144/6).astype(int))

# 삼각함수를 이용한 시간변수 생성
min_in_day = 24*6
hour_in_day = 24

minute_sin = np.sin(np.pi*minute/min_in_day) 
minute_cos = np.cos(np.pi*minute/min_in_day)

hour_sin  = np.sin(np.pi*hour/hour_in_day)
hour_cos  = np.cos(np.pi*hour/hour_in_day)

# %%
X_test_norm['minute_sin'] = minute_sin
X_test_norm['minute_cos'] = minute_cos

X_test_norm['hour_sin'] = hour_sin
X_test_norm['hour_cos'] = hour_cos
X_test_norm
# Out:
#             X00       X02       X03  ...  minute_cos  hour_sin  hour_cos
# 0     -0.310974 -0.016672 -0.162202  ...    1.000000  0.000000  1.000000
# 1     -0.289775 -0.388455 -0.268517  ...    0.999762  0.000000  1.000000
# 2     -0.247376 -0.202563 -0.268517  ...    0.999048  0.000000  1.000000
# 3     -0.310974  0.726894 -0.693777  ...    0.997859  0.000000  1.000000
# 4     -0.374572 -0.388455 -0.800091  ...    0.996195  0.000000  1.000000
# ...         ...       ...       ...  ...         ...       ...       ...
# 11515  1.172980  2.214027  2.495669  ...   -0.994056  0.130526 -0.991445
# 11516  1.151781  1.377515  1.645150  ...   -0.996195  0.130526 -0.991445
# 11517  1.151781  2.121081  1.113576  ...   -0.997859  0.130526 -0.991445
# 11518  1.130581  0.819840  1.432521  ...   -0.999048  0.130526 -0.991445
# 11519  1.109382  1.377515  2.176725  ...   -0.999762  0.130526 -0.991445
#
# [11520 rows x 40 columns]

# %%
X_train_norm = X_train_norm.loc[:, X_train_norm.max() != X_train_norm.min()]
X_test_norm = X_test_norm.loc[:, X_test_norm.max() != X_test_norm.min()]
len(X_test_norm.columns) == len(X_train_norm.columns)
# Out:
# True

# %%
# 실제값과 예측값의 차이가 1보다 작은 건 무시하는 Custom MSE Metric
def mse1(y_pred, y_true):

    diff = abs(y_true - y_pred)
    mask_less_than_one = np.array([0 if x < 1 else 1 for x in diff])

    y_pred = mask_less_than_one * y_pred
    y_true = mask_less_than_one *y_true
    
    score =  mean_squared_error(y_true, y_pred)
    
    return 'score', score, False

# %%
X_train_30 = X_train_norm.iloc[:4320+4320+4320,:]
y_train_30 = y_train.iloc[:4320+4320+4320]
X_train_3 = X_train_norm.iloc[4320+4320+4320:,:]
y_train_3 = y_train.iloc[4320+4320+4320:]

# %%
selected_columns = ['X30',
                    'X00',
                    'X38',
                    'X20',
                    'X32',
                    'X37',
                    'X34',
                    'X07',
                    'X12','X13','X31','X11','X28','X18','minute_sin','X26','X02','X03','minute_cos','X01'
                    ]
                    #minute_sin,X37,minute_cos,X07,X38,X01,X20,X31,X11,X00,X29,hour_cos

# %%
X_train_30 =X_train_30[selected_columns]

X_train_3 = X_train_3[selected_columns]
test = X_test_norm[selected_columns]

# %%
pip install shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/a8/77/b504e43e21a2ba543a1ac4696718beb500cfa708af2fb57cb54ce299045c/shap-0.35.0.tar.gz (273kB)
#      |████████████████████████████████| 276kB 4.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.18.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (1.0.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.38.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->shap) (1.12.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.35.0-cp36-cp36m-linux_x86_64.whl size=394107 sha256=1b3873784188d850f254806a834f64405ca9ddc8f316a9c2622c338853ca1413
#   Stored in directory: /root/.cache/pip/wheels/e7/f7/0f/b57055080cf8894906b3bd3616d2fc2bfd0b12d5161bcb24ac
# Successfully built shap
# Installing collected packages: shap
# Successfully installed shap-0.35.0

# %%
import pandas as pd
import numpy as np

from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import gc

import shap

# %%
DEBUG = False

if DEBUG:
    NFOLDS = 2
    N_ESTIMATORS = 50
else:
    NFOLDS = 5
    N_ESTIMATORS = 2500

# %%
# Y15, Y16, Y18을 활용한 훈련데이터 세트 모델링

feature_importance = pd.DataFrame()
feature_importance['feature'] = X_train_30.columns

folds = KFold(n_splits=NFOLDS, shuffle=True)
y_preds = np.zeros(test.shape[0])

model = LGBMRegressor(n_estimators=N_ESTIMATORS,
                       boosting_type='gbdt',
                       num_leaves=60,
                       max_depth=-1,
                       learning_rate=0.01,
                       objective='regression',
                       sub_sample=0.7,
                       colsample_bytree=0.8,
                       min_data_in_leaf=100,
                       bagging_seed=11,
                      metrics="mae",
                       # metric=mse_ignoring_diff_less_than_one,
                       verbosity=-1,
                       random_state=47)

for fold_n, (train_index, valid_index) in enumerate(folds.split(X_train_30, y_train_30)):
    print('Fold: ', fold_n+1)
    X_train_fold, X_valid_fold = X_train_30.iloc[train_index], X_train_30.iloc[valid_index]
    y_train_fold, y_valid_fold = y_train_30.iloc[train_index], y_train_30.iloc[valid_index]
    
    evals = [(X_train_fold, y_train_fold), (X_valid_fold,  y_valid_fold)]
    model.fit(X_train_fold, 
              y_train_fold, 
              eval_metric=mse1,
              eval_set=evals,
              early_stopping_rounds=50,
              verbose=100
             )
    
    shap_values = shap.TreeExplainer(model.booster_).shap_values(X_train_fold)
    fold_importance = pd.DataFrame()
    fold_importance['feature'] = X_train_30.columns
    fold_importance['shap_values'] = abs(np.array(shap_values)[:, :].mean(0))
    fold_importance['feat_importance'] = model.feature_importances_
    feature_importance = pd.concat([feature_importance, fold_importance], sort=False)
        
    y_preds += model.predict(test) / NFOLDS
    
    del X_train_fold, X_valid_fold, y_train_fold, y_valid_fold
    gc.collect()

feature_importance = feature_importance.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
# Out:
# Fold:  1
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l1: 2.62613	training's score: 9.4926	valid_1's l1: 2.63649	valid_1's score: 9.60286
# [200]	training's l1: 1.09051	training's score: 1.60658	valid_1's l1: 1.11829	valid_1's score: 1.69134
# [300]	training's l1: 0.582676	training's score: 0.381751	valid_1's l1: 0.631648	valid_1's score: 0.477893
# [400]	training's l1: 0.424495	training's score: 0.185768	valid_1's l1: 0.480227	valid_1's score: 0.273843
# [500]	training's l1: 0.36304	training's score: 0.126146	valid_1's l1: 0.420984	valid_1's score: 0.210148
# [1400]	training's l1: 0.196802	training's score: 0.0132575	valid_1's l1: 0.262056	valid_1's score: 0.0532631
# [1500]	training's l1: 0.187509	training's score: 0.00989799	valid_1's l1: 0.253675	valid_1's score: 0.0473316
# [1600]	training's l1: 0.179055	training's score: 0.00789036	valid_1's l1: 0.245778	valid_1's score: 0.0428997
# [1700]	training's l1: 0.170739	training's score: 0.00625449	valid_1's l1: 0.237839	valid_1's score: 0.0393897
# [1800]	training's l1: 0.163581	training's score: 0.0047296	valid_1's l1: 0.23103	valid_1's score: 0.035549
# [1900]	training's l1: 0.157056	training's score: 0.00355966	valid_1's l1: 0.224693	valid_1's score: 0.0336463
# [2000]	training's l1: 0.151035	training's score: 0.00314223	valid_1's l1: 0.218806	valid_1's score: 0.0325608
# [2100]	training's l1: 0.145416	training's score: 0.00266899	valid_1's l1: 0.213292	valid_1's score: 0.031909
# [2200]	training's l1: 0.139693	training's score: 0.00221228	valid_1's l1: 0.207621	valid_1's score: 0.0301262
# [2300]	training's l1: 0.134647	training's score: 0.00163123	valid_1's l1: 0.202539	valid_1's score: 0.0291963
# [2400]	training's l1: 0.129838	training's score: 0.00155376	valid_1's l1: 0.197911	valid_1's score: 0.0287471
# [2500]	training's l1: 0.125365	training's score: 0.00128639	valid_1's l1: 0.193339	valid_1's score: 0.0279721
# Did not meet early stopping. Best iteration is:
# [2500]	training's l1: 0.125365	training's score: 0.00128639	valid_1's l1: 0.193339	valid_1's score: 0.0279721
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  5
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l1: 2.63234	training's score: 9.53077	valid_1's l1: 2.63768	valid_1's score: 9.59269
# [200]	training's l1: 1.09175	training's score: 1.61638	valid_1's l1: 1.11812	valid_1's score: 1.70786
# [300]	training's l1: 0.585087	training's score: 0.379898	valid_1's l1: 0.628458	valid_1's score: 0.440099
# [400]	training's l1: 0.423864	training's score: 0.186481	valid_1's l1: 0.473765	valid_1's score: 0.232332
# [500]	training's l1: 0.362061	training's score: 0.12423	valid_1's l1: 0.413943	valid_1's score: 0.168516
# [600]	training's l1: 0.325985	training's score: 0.0881871	valid_1's l1: 0.380429	valid_1's score: 0.130607
# [700]	training's l1: 0.298527	training's score: 0.0673404	valid_1's l1: 0.355369	valid_1's score: 0.109632
# [800]	training's l1: 0.276752	training's score: 0.0518867	valid_1's l1: 0.336038	valid_1's score: 0.0938551
# [900]	training's l1: 0.258511	training's score: 0.0415861	valid_1's l1: 0.320252	valid_1's score: 0.0813834
# [1000]	training's l1: 0.242375	training's score: 0.0333681	valid_1's l1: 0.305651	valid_1's score: 0.0727207
# [1100]	training's l1: 0.228262	training's score: 0.026242	valid_1's l1: 0.293183	valid_1's score: 0.0628462
# [1200]	training's l1: 0.216095	training's score: 0.0199365	valid_1's l1: 0.282554	valid_1's score: 0.054791
# [1300]	training's l1: 0.20533	training's score: 0.0165585	valid_1's l1: 0.273021	valid_1's score: 0.0501518
# [1400]	training's l1: 0.19519	training's score: 0.0138926	valid_1's l1: 0.263754	valid_1's score: 0.0442487
# [1500]	training's l1: 0.185822	training's score: 0.0111195	valid_1's l1: 0.255062	valid_1's score: 0.0402866
# [1600]	training's l1: 0.177648	training's score: 0.00871383	valid_1's l1: 0.247729	valid_1's score: 0.0362112
# [1700]	training's l1: 0.170139	training's score: 0.00742628	valid_1's l1: 0.240689	valid_1's score: 0.0320785
# [1800]	training's l1: 0.162925	training's score: 0.00580702	valid_1's l1: 0.233782	valid_1's score: 0.0281932
# [1900]	training's l1: 0.156414	training's score: 0.00490253	valid_1's l1: 0.227766	valid_1's score: 0.0259218
# [2000]	training's l1: 0.150419	training's score: 0.00431407	valid_1's l1: 0.221767	valid_1's score: 0.0236203
# [2100]	training's l1: 0.144537	training's score: 0.00386748	valid_1's l1: 0.216179	valid_1's score: 0.0222507
# [2200]	training's l1: 0.139245	training's score: 0.00298466	valid_1's l1: 0.210976	valid_1's score: 0.0206511
# [2300]	training's l1: 0.134069	training's score: 0.00243089	valid_1's l1: 0.205745	valid_1's score: 0.0167692
# [2400]	training's l1: 0.129273	training's score: 0.00192397	valid_1's l1: 0.200823	valid_1's score: 0.0153809
# [2500]	training's l1: 0.124793	training's score: 0.00181707	valid_1's l1: 0.19616	valid_1's score: 0.0148207
# Did not meet early stopping. Best iteration is:
# [2500]	training's l1: 0.124793	training's score: 0.00181707	valid_1's l1: 0.19616	valid_1's score: 0.0148207
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
# Y15, Y16, Y18을 활용한 훈련데이터 세트 모델링

feature_importance = pd.DataFrame()
feature_importance['feature'] = X_train_3.columns

folds = KFold(n_splits=NFOLDS, shuffle=True)
y_preds_3 = np.zeros(test.shape[0])

model_3 = LGBMRegressor(n_estimators=N_ESTIMATORS,
                       boosting_type='gbdt',
                       num_leaves=60,
                       max_depth=-1,
                       learning_rate=0.01,
                       objective='regression',
                      #metrics="mae",
                       sub_sample=0.7,
                       colsample_bytree=0.8,
                       min_data_in_leaf=100,
                       bagging_seed=11,
                       # metric=mse_ignoring_diff_less_than_one,
                       verbosity=-1,
                       random_state=47)

for fold_n, (train_index, valid_index) in enumerate(folds.split(X_train_3, y_train_3)):
    print('Fold: ', fold_n+1)
    X_train_fold, X_valid_fold = X_train_3.iloc[train_index], X_train_3.iloc[valid_index]
    y_train_fold, y_valid_fold = y_train_3.iloc[train_index], y_train_3.iloc[valid_index]
    
    evals = [(X_train_fold, y_train_fold), (X_valid_fold,  y_valid_fold)]
    model_3.fit(X_train_fold, 
              y_train_fold, 
              eval_metric=mse1,
              eval_set=evals,
              early_stopping_rounds=50,
              verbose=100
             )
    
    shap_values = shap.TreeExplainer(model_3.booster_).shap_values(X_train_fold)
    fold_importance = pd.DataFrame()
    fold_importance['feature'] = X_train_3.columns
    fold_importance['shap_values'] = abs(np.array(shap_values)[:, :].mean(0))
    fold_importance['feat_importance'] = model_3.feature_importances_
    feature_importance = pd.concat([feature_importance, fold_importance], sort=False)
        
    y_preds_3 += model_3.predict(test) / NFOLDS
    
    del X_train_fold, X_valid_fold, y_train_fold, y_valid_fold
    gc.collect()

feature_importance = feature_importance.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()

# %%
ensemble_lgb = 0.6 * y_preds + 0.4 * y_preds_3

submit = pd.DataFrame({'id':range(144*33, 144*113),
              'Y18':ensemble_lgb})
submit.to_csv('ensemble_lgbm_result.csv', index = False)
